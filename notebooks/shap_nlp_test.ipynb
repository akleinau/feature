# %%
import transformers
import shap

# %%
# load a transformers pipeline model
from transformers import pipeline
model = pipeline(task='sentiment-analysis', return_all_scores=True)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# H:\feature\.venv11\Lib\site-packages\transformers\pipelines\text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
# explain the model on two sample inputs
explainer = shap.Explainer(model)
shap_values = explainer(["What a great movie! ...if you have no taste."])
# Out:
#   0%|          | 0/240 [00:00<?, ?it/s]

# %%
# visualize the first prediction's explanation for the POSITIVE output class
shap.plots.text(shap_values[0, :, "POSITIVE"])
# Out:
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.56890395430826%" y1="33" x2="49.56890395430826%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.56890395430826%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="33.58358469454827%" y1="33" x2="33.58358469454827%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.58358469454827%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="17.59826543478828%" y1="33" x2="17.59826543478828%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="17.59826543478828%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="65.55422321406824%" y1="33" x2="65.55422321406824%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.55422321406824%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="81.53954247382822%" y1="33" x2="81.53954247382822%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.53954247382822%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.3</text><line x1="34.453627319122845%" y1="33" x2="34.453627319122845%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.453627319122845%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.416328</text><text x="34.453627319122845%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.416328</text><text x="34.453627319122845%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="65.54637214803319%" y1="33" x2="65.54637214803319%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.54637214803319%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999853</text><text x="65.54637214803319%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.999853</text><text x="65.54637214803319%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">POSITIVE</tspan>(inputs)</text><rect x="8.333333288929671%" width="57.21303885910353%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="26.10941438742723%" x2="65.54637214803319%" y1="60" y2="60" id="_fb_ksrmbpnklfnzbazytzac_ind_3" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="45.827893267730204%" y="71" font-size="12px" id="_fs_ksrmbpnklfnzbazytzac_ind_3" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.74</text><svg x="26.10941438742723%" y="40" height="20" width="39.43695776060596%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">great</text>  </svg></svg><line x1="19.669862307048703%" x2="26.10941438742723%" y1="60" y2="60" id="_fb_ksrmbpnklfnzbazytzac_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="22.889638347237966%" y="71" font-size="12px" id="_fs_ksrmbpnklfnzbazytzac_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.121</text><svg x="19.669862307048703%" y="40" height="20" width="6.439552080378526%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9 ...
